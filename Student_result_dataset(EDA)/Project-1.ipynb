# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Expanded_data_with_more_features.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (30641, 15)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 2               2  female     group B     master's degree      standard
# 4               4    male     group C        some college      standard
# 5               5  female     group B  associate's degree      standard
# 6               6  female     group B        some college      standard
# 7               7    male     group B        some college  free/reduced
# ...           ...     ...         ...                 ...           ...
# 30635         794    male     group C        some college      standard
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df['WklyStudyHours']=df['WklyStudyHours'].str.replace('10-15','5-10')

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df.EthnicGroup
# Out:
# 0            NaN
# 1        group C
# 2        group B
# 3        group A
# 4        group C
#           ...
# 30636    group D
# 30637    group E
# 30638        NaN
# 30639    group D
# 30640    group B
# Name: EthnicGroup, Length: 30641, dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.EthnicGroup.mode()
# Out:
# 0    group C
# Name: EthnicGroup, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
df.ParentEduc.mode()
# Out:
# 0    some college
# Name: ParentEduc, dtype: object

# %%
df['Unnamed: 0']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 30636    816
# 30637    890
# 30638    911
# 30639    934
# 30640    960
# Name: Unnamed: 0, Length: 30641, dtype: int64

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
df.shape
# Out:
# (30641, 14)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# null values are more but independent so not neccessary to fill it else:
# we can fill the categorial values with the mode() of the columns 
# so we can go ahead with null values 
# as the main dependent columns are mathscore reading score and writingscore so we can tackle it without :
# filling the null values of independent columns

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
ax=sns.countplot(x='EthnicGroup',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '9212'),
#  Text(0, 0, '5826'),
#  Text(0, 0, '2219'),
#  Text(0, 0, '7503'),
#  Text(0, 0, '4041')]

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(x='ParentEduc',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3386'),
#  Text(0, 0, '6633'),
#  Text(0, 0, '2023'),
#  Text(0, 0, '5550'),
#  Text(0, 0, '5687'),
#  Text(0, 0, '5517')]

# %%
ax=sns.countplot(x='ParentMaritalStatus',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '16844'),
#  Text(0, 0, '7097'),
#  Text(0, 0, '591'),
#  Text(0, 0, '4919')]

# %%
gb=df.groupby('ParentEduc').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})
gb
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
sns.heatmap(gb,annot=True)
# Out:
# <Axes: ylabel='ParentEduc'>

# %%
# parent's with higher education has there children more Score

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
#lets see whether ParentMaritalStaturs has any effect on studnents score

# %%
gbp=df.groupby('ParentMaritalStatus').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
gbp
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
sns.heatmap(gbp,annot=True)
# Out:
# <Axes: ylabel='ParentMaritalStatus'>

# %%
#parent's maritalstatus does'nt effect of has null effect

# %%
#lets compore students workly hours have any effect on there result

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
gbw=df.groupby('WklyStudyHours').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
gbw
# Out:
#                 MathScore  ReadingScore  WritingScore
# WklyStudyHours
# 10-May          66.870491     69.660532     68.636280
# < 5             64.580359     68.176135     67.090192
# > 10            68.696655     70.365436     69.777778

# %%
sns.heatmap(gbw,annot=True)
# Out:
# <Axes: ylabel='WklyStudyHours'>

# %%
df.WklyStudyHours
# Out:
# 0           < 5
# 1        10-May
# 2           < 5
# 3        10-May
# 4        10-May
#           ...
# 30636    10-May
# 30637    10-May
# 30638    10-May
# 30639    10-May
# 30640    10-May
# Name: WklyStudyHours, Length: 30641, dtype: object

# %%
ax=sns.barplot(x='WklyStudyHours',y='MathScore',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '64.5804'), Text(0, 0, '66.8705'), Text(0, 0, '68.6967')]

# %%
#Students wklyhours ie> >10 have more score in studies next is 5-10 hrs

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
ax=sns.countplot(x='Gender',hue='WklyStudyHours',data=df)
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '8209'), Text(0, 0, '8037')]

# %%
# average students spend wklyhours between 5-10

# %%
df.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard      NaN
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# ...

# %%
ax=sns.barplot(x='Gender',y='MathScore',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '64.0807'), Text(0, 0, '69.0699')]

# %%
gbg=df.groupby('Gender').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
sns.heatmap(gbg,annot=True)
# Out:
# <Axes: ylabel='Gender'>

# %%
#female scores more marks in ReadingScore and WritingScore but probabily less in maths

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
gbs=df.groupby('IsFirstChild').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
sns.heatmap(gbs,annot=True)
# Out:
# <Axes: ylabel='IsFirstChild'>

# %% [markdown]
# # Conclusion

# %%
# from the following data we get following insights:
# number of females are more than the males  
# parent's with higher education has there children more Score
#parent's maritalstatus does'nt effect of has null effect
#Students wklyhours ie> >10 have more score in studies next is 5-10 hrs
# average students spend wklyhours between 5-10
#female scores more marks in ReadingScore and WritingScore but probabily less in maths
#Generally students are low in maths
#Group E students are have scored more / are more clever

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='MathScore')
# Out:
# <Axes: xlabel='MathScore'>

# %%
sns.boxplot(data=df,x='ReadingScore')
# Out:
# <Axes: xlabel='ReadingScore'>

# %%
sns.boxplot(data=df,x='WritingScore')
# Out:
# <Axes: xlabel='WritingScore'>

# %%
#Generally students are low in maths

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
df['EthnicGroup'].unique()
# Out:
# array([nan, 'group C', 'group B', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df.EthnicGroup.value_counts()
# Out:
# EthnicGroup
# group C    9212
# group D    7503
# group B    5826
# group E    4041
# group A    2219
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='EthnicGroup',data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '9212'),
#  Text(0, 0, '5826'),
#  Text(0, 0, '2219'),
#  Text(0, 0, '7503'),
#  Text(0, 0, '4041')]

# %%
GroupA=df.loc[(df['EthnicGroup']=='group A')].count()
GroupB=df.loc[(df['EthnicGroup']=='group B')].count()
GroupC=df.loc[(df['EthnicGroup']=='group C')].count()
GroupD=df.loc[(df['EthnicGroup']=='group D')].count()
GroupE=df.loc[(df['EthnicGroup']=='group E')].count()

# %%
labels=['GroupA','GroupB','GroupC','GroupD','GroupE']
values=[GroupA['EthnicGroup'],GroupB['EthnicGroup'],GroupC['EthnicGroup'],GroupD['EthnicGroup'],GroupE['EthnicGroup']]
plt.pie(values,labels=labels,  autopct='%1.2f%%',explode=[0,0,0.01,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd1a891a30>,
# ...
#  [Text(1.0679343156670604, 0.2636594345376768, 'GroupA'),
#   Text(0.47965667034074383, 0.9899138743333337, 'GroupB'),
#   Text(-1.0301294600184476, 0.41344080060161215, 'GroupC'),
#   Text(-0.1417295852362736, -1.0908312081476006, 'GroupD'),
#   Text(0.9948566006880766, -0.4693190216338617, 'GroupE')],
#  [Text(0.5825096267274875, 0.143814237020551, '7.70%'),
#   Text(0.2616309110949511, 0.5399530223636365, '20.23%'),
#   Text(-0.5661071807308585, 0.22720620573602107, '31.99%'),
#   Text(-0.07730704649251287, -0.5949988408077821, '26.05%'),
#   Text(0.542649054920769, -0.25599219361847, '14.03%')])

# %%
sns.barplot(x='EthnicGroup',y='MathScore',data=df)
# Out:
# <Axes: xlabel='EthnicGroup', ylabel='MathScore'>

# %%
sns.barplot(x='EthnicGroup',y='WritingScore',data=df)
# Out:
# <Axes: xlabel='EthnicGroup', ylabel='WritingScore'>

# %%
sns.barplot(x='EthnicGroup',y='ReadingScore',data=df)
# Out:
# <Axes: xlabel='EthnicGroup', ylabel='ReadingScore'>

# %%
#Group E students are have scored more / are more clever
